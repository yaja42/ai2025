# %% [markdown]
# # NLP Module 22 - Practical Exercise
# ## Ingest, cleanse, and analyze BBC news

# %% [markdown]
# ### Tokenization

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import re
import pandas as pd

# %%
data = pd.read_csv('resources/bbc_news.csv')
data.info()
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   index        1000 non-null   int64
#  2   title        1000 non-null   object
#  3   pubDate      1000 non-null   object
#  4   guid         1000 non-null   object
#  5   link         1000 non-null   object
#  6   description  1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB
#    Unnamed: 0  index                                              title  \
# 0           0   6684                              Can I refuse to work?
# 1           1   9267  'Liz Truss the Brief?' World reacts to UK poli...
# 2           2   7387  Rationing energy is nothing new for off-grid c...
# 3           3    767  The hunt for superyachts of sanctioned Russian...
# 4           4   3712  Platinum Jubilee: 70 years of the Queen in 70 ...
# 5           5   8967  Red Bull found guilty of breaking Formula 1's ...
# 6           6  10858  World Triathlon Championship Series: Flora Duf...
# 7           7  14914  Terry Hall: Coventry scooter ride-out pays tri...
# 8           8   8934  Post Office and Fujitsu to face inquiry over H...
# 9           9   4879                    'Pavement parking frightens me'
#
#                          pubDate  \
# 0  Wed, 10 Aug 2022 15:46:18 GMT
# 1  Mon, 17 Oct 2022 11:35:12 GMT
# 2  Wed, 31 Aug 2022 05:20:18 GMT
# 3  Tue, 22 Mar 2022 14:37:01 GMT
# 4  Wed, 01 Jun 2022 23:17:33 GMT
# 5  Mon, 10 Oct 2022 15:23:47 GMT
# 6  Fri, 25 Nov 2022 14:22:09 GMT
# 7  Sun, 19 Mar 2023 16:42:11 GMT
# 8  Mon, 10 Oct 2022 21:00:45 GMT
# 9  Fri, 01 Jul 2022 23:02:09 GMT
#
#                                                 guid  \
# 0       https://www.bbc.co.uk/news/business-62147992
# 1          https://www.bbc.co.uk/news/world-63285480
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3                https://www.bbc.co.uk/news/60739336
# 4             https://www.bbc.co.uk/news/uk-61660128
# 5      https://www.bbc.co.uk/sport/formula1/63204082
# 6     https://www.bbc.co.uk/sport/triathlon/63756049
# 7  https://www.bbc.co.uk/news/uk-england-coventry...
# 8       https://www.bbc.co.uk/news/business-63205335
# 9  https://www.bbc.co.uk/news/uk-england-nottingh...
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/business-62147992?a...
# 1  https://www.bbc.co.uk/news/world-63285480?at_m...
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3  https://www.bbc.co.uk/news/60739336?at_medium=...
# 4  https://www.bbc.co.uk/news/uk-61660128?at_medi...
# 5  https://www.bbc.co.uk/sport/formula1/63204082?...
# 6  https://www.bbc.co.uk/sport/triathlon/63756049...
# 7  https://www.bbc.co.uk/news/uk-england-coventry...
# 8  https://www.bbc.co.uk/news/business-63205335?a...
# 9  https://www.bbc.co.uk/news/uk-england-nottingh...
#
#                                          description
# 0  With much of the UK enduring another period of...
# 1  The UK's political chaos has been watched arou...
# 2  Scoraig in the north west Highlands has long h...
# 3  Wealthy Russians sanctioned by the US, EU and ...
# 4  A quick look back at the Queen's 70 years on t...
# 5  Red Bull are found guilty of breaking Formula ...
# 6  Bermuda's Flora Duffy gets the better of Brita...
# 7  Hundreds of people ride through Coventry on wh...
# 8  The public inquiry is taking further evidence ...
# 9  Ted, who is blind, hopes people will reconside...

# %%
# cleanse 1. lowercase 2. remove stopwords 3. remove punct
data['title_lowercase'] = data['title'].apply(lambda x: x.lower())
data['title_lowercase'][:5]
# Out:
# 0                                can i refuse to work?
# 1    'liz truss the brief?' world reacts to uk poli...
# 2    rationing energy is nothing new for off-grid c...
# 3    the hunt for superyachts of sanctioned russian...
# 4    platinum jubilee: 70 years of the queen in 70 ...
# Name: title_lowercase, dtype: object

# %%
stop_words = set(stopwords.words('english'))
stop_words.remove('not')
data['title_lowercase_no_stopwords'] = data['title_lowercase'].apply(lambda x: ' '.join(word for word in x.split() if word not in stop_words))
data['title_lowercase_no_stopwords'][:10]
# Out:
# 0                                         refuse work?
# 1    'liz truss brief?' world reacts uk political t...
# 2      rationing energy nothing new off-grid community
# 3        hunt superyachts sanctioned russian oligarchs
# 4          platinum jubilee: 70 years queen 70 seconds
# 5    red bull found guilty breaking formula 1's bud...
# 6    world triathlon championship series: flora duf...
# 7    terry hall: coventry scooter ride-out pays tri...
# 8     post office fujitsu face inquiry horizon scandal
# 9                      'pavement parking frightens me'
# Name: title_lowercase_no_stopwords, dtype: object

# %%
data['title_lowercase_no_punct'] = data['title_lowercase'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
data['title_lowercase_no_punct'][:5]
# Out:
# 0                                 can i refuse to work
# 1    liz truss the brief world reacts to uk politic...
# 2    rationing energy is nothing new for offgrid co...
# 3    the hunt for superyachts of sanctioned russian...
# 4    platinum jubilee 70 years of the queen in 70 s...
# Name: title_lowercase_no_punct, dtype: object

# %%
# tokenization
data['tokenized'] = data.apply(lambda row: word_tokenize(row['title_lowercase_no_punct']), axis=1)
data['tokenized'][:5]
# Out:
# 0                           [can, i, refuse, to, work]
# 1    [liz, truss, the, brief, world, reacts, to, uk...
# 2    [rationing, energy, is, nothing, new, for, off...
# 3    [the, hunt, for, superyachts, of, sanctioned, ...
# 4    [platinum, jubilee, 70, years, of, the, queen,...
# Name: tokenized, dtype: object

# %%
# lemmartization
wl = WordNetLemmatizer()
data['lemmatized'] = data['tokenized'].apply(lambda tokens: [wl.lemmatize(token) for token in tokens])
data['lemmatized'][:5]
# Out:
# 0                           [can, i, refuse, to, work]
# 1    [liz, truss, the, brief, world, reacts, to, uk...
# 2    [rationing, energy, is, nothing, new, for, off...
# 3    [the, hunt, for, superyachts, of, sanctioned, ...
# 4    [platinum, jubilee, 70, year, of, the, queen, ...
# Name: lemmatized, dtype: object

# %%
# extract all lemmars into a list
lemmars_clean = sum(data['lemmatized'], [])
print(lemmars_clean[:50])
# Out:
# ['can', 'i', 'refuse', 'to', 'work', 'liz', 'truss', 'the', 'brief', 'world', 'reacts', 'to', 'uk', 'political', 'turmoil', 'rationing', 'energy', 'is', 'nothing', 'new', 'for', 'offgrid', 'community', 'the', 'hunt', 'for', 'superyachts', 'of', 'sanctioned', 'russian', 'oligarch', 'platinum', 'jubilee', '70', 'year', 'of', 'the', 'queen', 'in', '70', 'second', 'red', 'bull', 'found', 'guilty', 'of', 'breaking', 'formula', '1', 'budget']

# %%
# statistics
unigram = pd.Series(nltk.ngrams(lemmars_clean, 1)).value_counts()
bigram = pd.Series(nltk.ngrams(lemmars_clean, 2)).value_counts()
trigram = pd.Series(nltk.ngrams(lemmars_clean, 3)).value_counts()
#print(unigram[:10])
#print(bigram[:10])
print(trigram[:10])
# Out:
# (world, cup, 2022)       21
# (cost, of, living)       15
# (world, cup, england)     9
# (what, is, the)           7
# (of, the, week)           7
# (quiz, of, the)           5
# (week, in, picture)       5
# (england, v, south)       5
# (v, south, africa)        5
# (t20, world, cup)         5
# Name: count, dtype: int64

# %% [markdown]
# ### Tagging

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
spacy_doc = nlp(' '.join(lemmars_clean))
print(spacy_doc)
# Out:
# can i refuse to work liz truss the brief world reacts to uk political turmoil rationing energy is nothing new for offgrid community the hunt for superyachts of sanctioned russian oligarch platinum jubilee 70 year of the queen in 70 second red bull found guilty of breaking formula 1 budget cap world triathlon championship series flora duffy beat georgia taylorbrown to womens title terry hall coventry scooter rideout pay tribute to singer post office and fujitsu to face inquiry over horizon scandal pavement parking frightens me uk interest rate how will the rise affect you and how high could it go they stayed for the storm what happens now six nation can scotland best since 99 beat best ireland ever how long can liz truss survive a prime minister platinum jubilee beacon light across the globe to celebrate queen reign top student loan interest rate cut by 5 in england russian said theyd take my baby a medic story week in picture 1117 june 2022 xi jinping in hong kong tight security a city mark 25 year of handover rescue carried out in silence to listen for sound of life nick pope newcastle goalkeeper extends incredible clean sheet record how china plan to become the next big space power barcelona thrash leader real madrid in famous clasico win kuenssberg the budget can not mask big change to our economy nicola bulley search what we know about her disappearance cost of living can christmas light display survive the energy crisis the 100yearold edinburgh man still working three day a week freya the 600kg walrus cause a stir in norway how can i offer a uk home to ukrainian refugee nicola bulley search former police bos say criticism is unfair don bolduc democrat elevated this republican will it backfire some strike action cancelled after the queen death the neighbourhood leading a green energy revolution men u17 european championship dutch 17yearold isaac babadi score panenka penalty amtrak derailment three killed in missouri after train hit truck energy price cap rising bill four discount and payment that could help you environment are mushroom board the future of surfing flying boat and other tech for cleaner shipping scottish football to ban heading the day before and after match chris eubank jr v liam smith what next for boxing after unacceptable taunt the town destroyed to make way for a whitesonly suburb ukraine war a village celebrates russian retreat root hit ton a england take command against west indie heineken champion cup leicester 166 edinburgh jasper wiese try sends tiger into last eight world cup 2022 bellingham gakpo fernandez and other breakout star briton jack fenton killed in greek helicopter accident emotional sue barker get centre court ovation ukrainian skating sister back to doing what they love england v india edgbaston official investigate crowd racism at test newspaper headline rwanda plan will fail and sa train kyiv force my name is leon sir lenny henry brings moving adoption story to screen big brother star glyn wise plan to be priest minister asleep at the wheel over dentist shortage say lib dems chris kaba met suspends officer who shot dead unarmed man world cup 2022 what we learned from a group stage that saw record number of upset james webb nasa space telescope delivers spectacular picture constitution hill cheltenham champion hurdle winner the horse of a generation at least one victim could have survived arena bomb inquiry gareth bale wale captain retires from football aged 33 ukraine war silent street in wiped out donetsk town world cup 2022 vittorio pozzos legacy and a record that might finally be under threat train strike worker vote on further six month of walkout eidevall 100 sure arsenal will advance after firstleg draw ukraine war returning to the place my father wa killed furniture firm made collapse customer in the dark over refund widow of u capitol riot officer on stigma of his death nh reach deal for lifesaving breastcancer drug giant ceramic sculpture by sandy brown ha been unveiled in  ...

# %%
pos_df = pd.DataFrame(columns=['token', 'pos_tag'])

# %%
for token in spacy_doc:
    pos_df = pd.concat([pos_df, pd.DataFrame.from_records([{'token': token.text, 'pos_tag': token.pos_}])], ignore_index=True)
pos_df.head(10)
# Out:
#     token pos_tag
# 0     can     AUX
# 1       i    PRON
# 2  refuse    VERB
# 3      to    PART
# 4    work    VERB
# 5     liz   PROPN
# 6   truss    VERB
# 7     the     DET
# 8   brief     ADJ
# 9   world    NOUN

# %%
# counts
count_b

# %%
from spacy import displacy

# %%
displacy.render(spacy_doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">can i refuse to work liz truss the brief world reacts to uk political turmoil rationing energy is nothing new for offgrid community the hunt for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     superyachts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of sanctioned
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  oligarch platinum jubilee
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the queen in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     70 second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  red
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bull
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  found guilty of breaking formula
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  budget cap world triathlon championship series flora duffy beat
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     georgia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  taylorbrown to womens title
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     terry hall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  coventry scooter rideout pay tribute to singer post office and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fujitsu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to face inquiry over horizon scandal pavement parking frightens me uk interest rate how will the rise affect you and how high could it go they stayed for the storm what happens now
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  nation can scotland best since
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     99
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  beat best ireland ever how long can liz truss survive a prime minister platinum
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jubilee beacon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  light across the globe to celebrate queen reign top student loan interest rate cut by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     england
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  said theyd take my baby a medic story
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in picture
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1117 june 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  xi jinping in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hong kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  tight security a city mark
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of handover rescue carried out in silence to listen for sound of life
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nick pope
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     newcastle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  goalkeeper extends incredible clean sheet record how
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     china
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  plan to become the next big space power barcelona thrash leader real
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     madrid
#     <span style="font
